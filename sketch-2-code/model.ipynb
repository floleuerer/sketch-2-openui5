# %%
import os
import joblib
from keras.preprocessing.text import Tokenizer, one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Model, Sequential, model_from_json
from keras.utils import to_categorical
from keras.layers.core import Dense, Dropout, Flatten
from keras.optimizers import RMSprop
from keras.layers.convolutional import Conv2D
from keras.callbacks import ModelCheckpoint, CSVLogger
from keras.layers import Embedding, TimeDistributed, RepeatVector, LSTM, GRU, concatenate , Input, Reshape, Dense
import numpy as np

# %%
max_length = 20
tokenizer_split = '\n'
img_dim = 256

epochs = 300
batch_size = 128

img_dir = '../ressources/_img_test/'
page_dir = '../ressources/_xml_test/'

images = joblib.load(img_dir + 'img.dmp')
pages = joblib.load(page_dir + 'page.dmp')

# %%
# Initialize the function to create the vocabulary 
tokenizer = Tokenizer(filters='', split=tokenizer_split, lower=False)
tokenizer.fit_on_texts(pages)

joblib.dump(tokenizer, 'tokenizer.dmp')

# Add one spot for the empty word in the vocabulary 
vocab_size = len(tokenizer.word_index) + 1
# Map the input sentences into the vocabulary indexes
train_sequences = tokenizer.texts_to_sequences(pages)
# The longest set of boostrap tokens
max_sequence = max(len(s) for s in train_sequences)

# limit max_length -> max_sequence
if max_length > max_sequence:
    max_length = max_sequence

def preprocess_data(sequences, features):
    X, y, image_data = list(), list(), list()
    for img_no, seq in enumerate(sequences):
        for i in range(1, len(seq)):
            # Add the sentence until the current count(i) and add the current count to the output
            in_seq, out_seq = seq[:i], seq[i]
            # Pad all the input token sentences to max_sequence
            in_seq = pad_sequences([in_seq], maxlen=max_sequence)[0]
            # Turn the output into one-hot encoding
            out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
            # Add the corresponding image to the boostrap token file
            image_data.append(features[img_no])
            # Cap the input sentence to max_length tokens and add it
            X.append(in_seq[-max_length:])
            y.append(out_seq)
    return np.array(X), np.array(y), np.array(image_data)

X, y, image_data = preprocess_data(train_sequences, images)

# %%
#Create the encoder
image_model = Sequential()
image_model.add(Conv2D(16, (3, 3), padding='valid', activation='relu', input_shape=images[0].shape))
image_model.add(Conv2D(16, (3,3), activation='relu', padding='same', strides=2))
image_model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
image_model.add(Conv2D(32, (3,3), activation='relu', padding='same', strides=2))
image_model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
image_model.add(Conv2D(64, (3,3), activation='relu', padding='same', strides=2))
image_model.add(Conv2D(128, (3,3), activation='relu', padding='same'))

image_model.add(Flatten())
image_model.add(Dense(1024, activation='relu'))
image_model.add(Dropout(0.3))
image_model.add(Dense(1024, activation='relu'))
image_model.add(Dropout(0.3))

image_model.add(RepeatVector(max_length))

visual_input = Input(shape=images[0].shape)
encoded_image = image_model(visual_input)

language_input = Input(shape=(max_length,))
language_model = Embedding(vocab_size, 50, input_length=max_length, mask_zero=True)(language_input)
language_model = GRU(128, return_sequences=True)(language_model)
language_model = GRU(128, return_sequences=True)(language_model)

#Create the decoder
decoder = concatenate([encoded_image, language_model])
decoder = GRU(512, return_sequences=True)(decoder)
decoder = GRU(512, return_sequences=False)(decoder)
decoder = Dense(vocab_size, activation='softmax')(decoder)

# Compile the model
model = Model(inputs=[visual_input, language_input], outputs=decoder)
optimizer = RMSprop(lr=0.0001, clipvalue=1.0)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# save model
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# %%
csvlogger = CSVLogger('log.csv', append=False, separator=';')
filepath ="epoch-{epoch:04d}--val_loss-{val_loss:.4f}--loss-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=True, period=2)
callbacks = [checkpoint,csvlogger]

# Train the model
model.fit([image_data, X], y, 
          batch_size=batch_size, 
          shuffle=False, 
          validation_split=0.1, 
          callbacks=callbacks, 
          verbose=1, 
          epochs=epochs)
# Out:
# Train on 234 samples, validate on 26 samples
# Epoch 1/300
# 234/234 [==============================] - 85s 362ms/step - loss: 2.7005 - val_loss: 2.8439
# Epoch 2/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.7525 - val_loss: 2.6732
#
# Epoch 00002: saving model to epoch-0002--val_loss-2.6732--loss-2.7525.hdf5
# Epoch 3/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.6282 - val_loss: 2.6268
# Epoch 4/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.5495 - val_loss: 2.5883
#
# Epoch 00004: saving model to epoch-0004--val_loss-2.5883--loss-2.5495.hdf5
# Epoch 5/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.5078 - val_loss: 2.5453
# Epoch 6/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.4852 - val_loss: 2.5083
#
# Epoch 00006: saving model to epoch-0006--val_loss-2.5083--loss-2.4852.hdf5
# Epoch 7/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.4615 - val_loss: 2.5013
# Epoch 8/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.4218 - val_loss: 2.4608
#
# Epoch 00008: saving model to epoch-0008--val_loss-2.4608--loss-2.4218.hdf5
# Epoch 9/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.4044 - val_loss: 2.3882
# Epoch 10/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.3365 - val_loss: 2.3723
#
# Epoch 00010: saving model to epoch-0010--val_loss-2.3723--loss-2.3365.hdf5
# Epoch 11/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.3224 - val_loss: 2.3517
# Epoch 12/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.2950 - val_loss: 2.3375
#
# Epoch 00012: saving model to epoch-0012--val_loss-2.3375--loss-2.2950.hdf5
# Epoch 13/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.2611 - val_loss: 2.2851
# Epoch 14/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.2283 - val_loss: 2.2672
#
# Epoch 00014: saving model to epoch-0014--val_loss-2.2672--loss-2.2283.hdf5
# Epoch 15/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.2196 - val_loss: 2.2563
# Epoch 16/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.2117 - val_loss: 2.2602
#
# Epoch 00016: saving model to epoch-0016--val_loss-2.2602--loss-2.2117.hdf5
# Epoch 17/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.1643 - val_loss: 2.2280
# Epoch 18/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.1552 - val_loss: 2.2173
#
# Epoch 00018: saving model to epoch-0018--val_loss-2.2173--loss-2.1552.hdf5
# Epoch 19/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.1298 - val_loss: 2.1857
# Epoch 20/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.1038 - val_loss: 2.1656
#
# Epoch 00020: saving model to epoch-0020--val_loss-2.1656--loss-2.1038.hdf5
# Epoch 21/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.0757 - val_loss: 2.1364
# Epoch 22/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.0617 - val_loss: 2.1535
#
# Epoch 00022: saving model to epoch-0022--val_loss-2.1535--loss-2.0617.hdf5
# Epoch 23/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.0714 - val_loss: 2.1858
# Epoch 24/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.0678 - val_loss: 2.1764
#
# Epoch 00024: saving model to epoch-0024--val_loss-2.1764--loss-2.0678.hdf5
# Epoch 25/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.0517 - val_loss: 2.1123
# Epoch 26/300
# 234/234 [==============================] - 2s 7ms/step - loss: 2.0238 - val_loss: 2.0709
#
# Epoch 00026: saving model to epoch-0026--val_loss-2.0709--loss-2.0238.hdf5
# Epoch 27/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.9778 - val_loss: 2.0659
# Epoch 28/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.9803 - val_loss: 2.0517
#
# Epoch 00028: saving model to epoch-0028--val_loss-2.0517--loss-1.9803.hdf5
# Epoch 29/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.9772 - val_loss: 2.0120
# Epoch 30/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.9531 - val_loss: 1.9834
#
# Epoch 00030: saving model to epoch-0030--val_loss-1.9834--loss-1.9531.hdf5
# Epoch 31/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.9536 - val_loss: 1.9800
# Epoch 32/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.9996 - val_loss: 1.9824
#
# Epoch 00032: saving model to epoch-0032--val_loss-1.9824--loss-1.9996.hdf5
# Epoch 33/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.9995 - val_loss: 1.9652
# Epoch 34/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8875 - val_loss: 1.9498
#
# Epoch 00034: saving model to epoch-0034--val_loss-1.9498--loss-1.8875.hdf5
# Epoch 35/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8946 - val_loss: 1.9560
# Epoch 36/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8710 - val_loss: 2.0024
#
# Epoch 00036: saving model to epoch-0036--val_loss-2.0024--loss-1.8710.hdf5
# Epoch 37/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.9073 - val_loss: 2.1611
# Epoch 38/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.9822 - val_loss: 1.9984
#
# Epoch 00038: saving model to epoch-0038--val_loss-1.9984--loss-1.9822.hdf5
# Epoch 39/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8923 - val_loss: 1.9663
# Epoch 40/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8471 - val_loss: 1.9531
#
# Epoch 00040: saving model to epoch-0040--val_loss-1.9531--loss-1.8471.hdf5
# Epoch 41/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8461 - val_loss: 1.9637
# Epoch 42/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8393 - val_loss: 2.0133
#
# Epoch 00042: saving model to epoch-0042--val_loss-2.0133--loss-1.8393.hdf5
# Epoch 43/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8608 - val_loss: 1.9854
# Epoch 44/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8528 - val_loss: 1.9662
#
# Epoch 00044: saving model to epoch-0044--val_loss-1.9662--loss-1.8528.hdf5
# Epoch 45/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8290 - val_loss: 1.9695
# Epoch 46/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8377 - val_loss: 1.9358
#
# Epoch 00046: saving model to epoch-0046--val_loss-1.9358--loss-1.8377.hdf5
# Epoch 47/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7890 - val_loss: 1.9027
# Epoch 48/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7859 - val_loss: 1.9213
#
# Epoch 00048: saving model to epoch-0048--val_loss-1.9213--loss-1.7859.hdf5
# Epoch 49/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7967 - val_loss: 1.9943
# Epoch 50/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8298 - val_loss: 1.9901
#
# Epoch 00050: saving model to epoch-0050--val_loss-1.9901--loss-1.8298.hdf5
# Epoch 51/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8242 - val_loss: 1.9006
# Epoch 52/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7683 - val_loss: 1.8716
#
# Epoch 00052: saving model to epoch-0052--val_loss-1.8716--loss-1.7683.hdf5
# Epoch 53/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7507 - val_loss: 1.8767
# Epoch 54/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7479 - val_loss: 1.9566
#
# Epoch 00054: saving model to epoch-0054--val_loss-1.9566--loss-1.7479.hdf5
# Epoch 55/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8135 - val_loss: 2.0228
# Epoch 56/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8156 - val_loss: 1.8542
#
# Epoch 00056: saving model to epoch-0056--val_loss-1.8542--loss-1.8156.hdf5
# Epoch 57/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7258 - val_loss: 1.8466
# Epoch 58/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7203 - val_loss: 1.8508
#
# Epoch 00058: saving model to epoch-0058--val_loss-1.8508--loss-1.7203.hdf5
# Epoch 59/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7289 - val_loss: 1.9169
# Epoch 60/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7815 - val_loss: 2.0529
#
# Epoch 00060: saving model to epoch-0060--val_loss-2.0529--loss-1.7815.hdf5
# Epoch 61/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.8156 - val_loss: 1.8154
# Epoch 62/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6964 - val_loss: 1.8116
#
# Epoch 00062: saving model to epoch-0062--val_loss-1.8116--loss-1.6964.hdf5
# Epoch 63/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6860 - val_loss: 1.8263
# Epoch 64/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7098 - val_loss: 1.9265
#
# Epoch 00064: saving model to epoch-0064--val_loss-1.9265--loss-1.7098.hdf5
# Epoch 65/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7699 - val_loss: 1.9518
# Epoch 66/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7618 - val_loss: 1.8167
#
# Epoch 00066: saving model to epoch-0066--val_loss-1.8167--loss-1.7618.hdf5
# Epoch 67/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6883 - val_loss: 1.7994
# Epoch 68/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6688 - val_loss: 1.8302
#
# Epoch 00068: saving model to epoch-0068--val_loss-1.8302--loss-1.6688.hdf5
# Epoch 69/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6926 - val_loss: 1.9376
# Epoch 70/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7524 - val_loss: 1.8837
#
# Epoch 00070: saving model to epoch-0070--val_loss-1.8837--loss-1.7524.hdf5
# Epoch 71/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7087 - val_loss: 1.7889
# Epoch 72/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6615 - val_loss: 1.7622
#
# Epoch 00072: saving model to epoch-0072--val_loss-1.7622--loss-1.6615.hdf5
# Epoch 73/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6479 - val_loss: 1.7704
# Epoch 74/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6498 - val_loss: 1.8742
#
# Epoch 00074: saving model to epoch-0074--val_loss-1.8742--loss-1.6498.hdf5
# Epoch 75/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7291 - val_loss: 2.0445
# Epoch 76/300
# 234/234 [==============================] - 2s 8ms/step - loss: 1.7790 - val_loss: 1.7444
#
# Epoch 00076: saving model to epoch-0076--val_loss-1.7444--loss-1.7790.hdf5
# Epoch 77/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6281 - val_loss: 1.7079
# Epoch 78/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6177 - val_loss: 1.6942
#
# Epoch 00078: saving model to epoch-0078--val_loss-1.6942--loss-1.6177.hdf5
# Epoch 79/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6406 - val_loss: 1.7297
# Epoch 80/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.7838 - val_loss: 1.7250
#
# Epoch 00080: saving model to epoch-0080--val_loss-1.7250--loss-1.7838.hdf5
# Epoch 81/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6477 - val_loss: 1.6937
# Epoch 82/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6232 - val_loss: 1.6889
#
# Epoch 00082: saving model to epoch-0082--val_loss-1.6889--loss-1.6232.hdf5
# Epoch 83/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6446 - val_loss: 1.7031
# Epoch 84/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6599 - val_loss: 1.7101
#
# Epoch 00084: saving model to epoch-0084--val_loss-1.7101--loss-1.6599.hdf5
# Epoch 85/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6470 - val_loss: 1.7023
# Epoch 86/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6287 - val_loss: 1.6933
#
# Epoch 00086: saving model to epoch-0086--val_loss-1.6933--loss-1.6287.hdf5
# Epoch 87/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6173 - val_loss: 1.6932
# Epoch 88/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6133 - val_loss: 1.6875
#
# Epoch 00088: saving model to epoch-0088--val_loss-1.6875--loss-1.6133.hdf5
# Epoch 89/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6113 - val_loss: 1.6972
# Epoch 90/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6216 - val_loss: 1.6967
#
# Epoch 00090: saving model to epoch-0090--val_loss-1.6967--loss-1.6216.hdf5
# Epoch 91/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6021 - val_loss: 1.6843
# Epoch 92/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.6079 - val_loss: 1.6847
#
# Epoch 00092: saving model to epoch-0092--val_loss-1.6847--loss-1.6079.hdf5
# Epoch 93/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.5691 - val_loss: 1.6741
# Epoch 94/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.5590 - val_loss: 1.6539
#
# Epoch 00094: saving model to epoch-0094--val_loss-1.6539--loss-1.5590.hdf5
# Epoch 95/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.5448 - val_loss: 1.6636
# Epoch 96/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.5558 - val_loss: 1.6720
#
# Epoch 00096: saving model to epoch-0096--val_loss-1.6720--loss-1.5558.hdf5
# Epoch 97/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.5656 - val_loss: 1.6962
# Epoch 98/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.5636 - val_loss: 1.6666
#
# Epoch 00098: saving model to epoch-0098--val_loss-1.6666--loss-1.5636.hdf5
# Epoch 99/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.5256 - val_loss: 1.6438
# Epoch 100/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.4677 - val_loss: 1.6251
#
# Epoch 00100: saving model to epoch-0100--val_loss-1.6251--loss-1.4677.hdf5
# Epoch 101/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.4843 - val_loss: 1.8987
# Epoch 102/300
# 234/234 [==============================] - 2s 8ms/step - loss: 1.6919 - val_loss: 1.7549
#
# Epoch 00102: saving model to epoch-0102--val_loss-1.7549--loss-1.6919.hdf5
# Epoch 103/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.5261 - val_loss: 1.7023
# Epoch 104/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.4855 - val_loss: 1.7054
#
# Epoch 00104: saving model to epoch-0104--val_loss-1.7054--loss-1.4855.hdf5
# Epoch 105/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.4762 - val_loss: 1.7056
# Epoch 106/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.4581 - val_loss: 1.7399
#
# Epoch 00106: saving model to epoch-0106--val_loss-1.7399--loss-1.4581.hdf5
# Epoch 107/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.4789 - val_loss: 1.7209
# Epoch 108/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.4595 - val_loss: 1.6724
#
# Epoch 00108: saving model to epoch-0108--val_loss-1.6724--loss-1.4595.hdf5
# Epoch 109/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.4136 - val_loss: 1.6544
# Epoch 110/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.4019 - val_loss: 1.7008
#
# Epoch 00110: saving model to epoch-0110--val_loss-1.7008--loss-1.4019.hdf5
# Epoch 111/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.4273 - val_loss: 1.7105
# Epoch 112/300
# 234/234 [==============================] - 2s 8ms/step - loss: 1.4333 - val_loss: 1.7518
#
# Epoch 00112: saving model to epoch-0112--val_loss-1.7518--loss-1.4333.hdf5
# Epoch 113/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.4266 - val_loss: 1.6757
# Epoch 114/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.3710 - val_loss: 1.6242
#
# Epoch 00114: saving model to epoch-0114--val_loss-1.6242--loss-1.3710.hdf5
# Epoch 115/300
# 234/234 [==============================] - 2s 8ms/step - loss: 1.3222 - val_loss: 1.6021
# Epoch 116/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.4542 - val_loss: 1.7183
#
# Epoch 00116: saving model to epoch-0116--val_loss-1.7183--loss-1.4542.hdf5
# Epoch 117/300
# 234/234 [==============================] - 2s 7ms/step - loss: 1.4303 - val_loss: 1.6737
# Epoch 118/300
# 234/234 [==============================] - 2s 8ms/step - loss: 1.4022 - val_loss: 1.6142
#
# Epoch 00118: saving model to epoch-0118--val_loss-1.6142--loss-1.4022.hdf5
# Epoch 119/300
# 234/234 [==============================] - 2s 8ms/step - loss: 1.3269 - val_loss: 1.5972
# Epoch 120/300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-400f75c4ac20> in <module>
#      11           callbacks=callbacks,
#      12           verbose=1,
# ---> 13           epochs=epochs)
#
# /anaconda/envs/py36/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# /anaconda/envs/py36/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# /anaconda/envs/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# /anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /anaconda/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# map an integer to a word
def word_for_id(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

# generate a description for an image
def generate_desc(model, tokenizer, photo, max_length):
    photo = np.array([photo])
    # seed the generation process
    in_text = '<!--START-->\n'
    # iterate over the whole length of the sequence
    print('\nPrediction---->\n\n<START> ', end='')
    for i in range(150):
        # integer encode input sequence
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        # pad input
        sequence = pad_sequences([sequence], maxlen=max_length)
        # predict next word
        yhat = model.predict([photo, sequence], verbose=0)
        # convert probability to integer
        yhat = np.argmax(yhat)
        # map integer to word
        word = word_for_id(yhat, tokenizer)
        # stop if we cannot map the word
        if word is None:
            break
        # append as input for generating the next word
        in_text += word + ' '
        # stop if we predict the end of the sequence
        print(word + '\n', end='')
        if word == '<!--END-->':
            break
    return in_text

# %%
test_image = images[0]
generate_desc(model, tokenizer, np.array(test_image), max_length)
# Out:
# Prediction---->
#
# <START> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# '<!--START-->\n<mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc"> <mvc:View displayBlock="true" xmlns="sap.m" ...

# %%
print(pages[0])
# Out:
# <!--START-->
# <mvc:View displayBlock="true" xmlns="sap.m" xmlns:mvc="sap.ui.core.mvc">
# <VBox class="sapUiSmallMargin">
# <Button text="Default" />
# <Switch state="true" />
# <CheckBox text="Option b" />
# <Input width="250px" class="sapUiSmallMarginBottom" />
# <CheckBox text="Option b" />
# <Button text="Accept" type="Accept" />
# <CheckBox text="Option b" />
# <Button text="Accept" type="Accept" />
# </VBox>
# </mvc:View>
# <!--END-->
